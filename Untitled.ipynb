# %%
# !pip install torch torchvision numpy pandas matplotlib scikit-learn Pillow
# Out:
# Requirement already satisfied: torch in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (2.7.1+cu118)
# Requirement already satisfied: torchvision in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (0.22.1+cu118)
# Requirement already satisfied: numpy in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (2.4.3)
# Requirement already satisfied: pandas in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (3.0.2)
# Requirement already satisfied: matplotlib in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (3.10.9)
# Requirement already satisfied: scikit-learn in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (1.8.0)
# Requirement already satisfied: Pillow in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (12.1.1)
# Requirement already satisfied: filelock in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\bilsr\anaconda3\envs\m1_env\Lib\site-packages (from jinja2->torch) (3.0.3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from PIL import Image
from collections import Counter

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import (DataLoader, Dataset,
                               WeightedRandomSampler)
from torchvision import models, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, precision_score,
                             recall_score, f1_score,
                             confusion_matrix, classification_report,
                             roc_curve, auc)
from sklearn.preprocessing import label_binarize

# %%
class XRayDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels      = labels
        self.transform   = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img = Image.open(self.image_paths[idx]).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.labels[idx]

# %%
DATASET_PATH = r"C:\Users\bilsr\OneDrive\Desktop\New folder\archive\chest_xray\chest_xray"

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

all_paths  = []
all_labels = []

CLASS_NAMES = ['Normal', 'Bacterial', 'Viral']

for split in ['train', 'test', 'val']:
    normal_folder = os.path.join(DATASET_PATH, split, 'NORMAL')
    if os.path.exists(normal_folder):
        for fname in os.listdir(normal_folder):
            if fname.lower().endswith(('.jpeg', '.jpg', '.png')):
                all_paths.append(os.path.join(normal_folder, fname))
                all_labels.append(0)

for split in ['train', 'test', 'val']:
    pneumonia_folder = os.path.join(DATASET_PATH, split, 'PNEUMONIA')
    if os.path.exists(pneumonia_folder):
        for fname in os.listdir(pneumonia_folder):
            if fname.lower().endswith(('.jpeg', '.jpg', '.png')):
                fpath = os.path.join(pneumonia_folder, fname)
                if 'bacteria' in fname.lower():
                    all_paths.append(fpath)
                    all_labels.append(1)
                elif 'virus' in fname.lower():
                    all_paths.append(fpath)
                    all_labels.append(2)

all_paths  = np.array(all_paths)
all_labels = np.array(all_labels)

print(f"Total images loaded : {len(all_paths)}")
print(f"Class distribution  :")
for i, name in enumerate(CLASS_NAMES):
    print(f"  {name}: {sum(all_labels == i)}")
# Out:
# Total images loaded : 5856
# Class distribution  :
#   Normal: 1583
#   Bacterial: 2780
#   Viral: 1493

# %%
def build_resnet50():
    model = models.resnet50(weights='IMAGENET1K_V1')

    for param in model.parameters():
        param.requires_grad = False

    for param in model.layer4.parameters():
        param.requires_grad = True

    num_features = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Linear(num_features, 256),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(256, 3)
    )
    return model

# Verify model
test_input  = torch.randn(1, 3, 224, 224)
test_output = build_resnet50()(test_input)
print("ResNet50 output shape:", test_output.shape)  # should be [1, 3]
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to C:\Users\bilsr/.cache\torch\hub\checkpoints\resnet50-0676ba61.pth
# 100.0%
# ResNet50 output shape: torch.Size([1, 3])

# %%
NUM_RUNS = 5
SEEDS    = [42, 7, 99, 2024, 13]
EPOCHS   = 50
BATCH    = 32
PATIENCE = 5
results  = []

device  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
pin_mem = True if torch.cuda.is_available() else False
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

for run, seed in enumerate(SEEDS, 1):
    print(f"\n{'='*55}")
    print(f"  RUN {run}  [seed={seed}]")
    print(f"{'='*55}")

    torch.manual_seed(seed)
    np.random.seed(seed)

    # Split
    X_train, X_test, y_train, y_test = train_test_split(
        all_paths, all_labels,
        test_size=0.2, random_state=seed, stratify=all_labels
    )

    # Handle class imbalance
    class_counts   = Counter(y_train)
    class_weights  = {cls: 1.0 / count for cls, count in class_counts.items()}
    sample_weights = [class_weights[label] for label in y_train]
    sampler = WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True
    )

    # Datasets and DataLoaders
    train_ds = XRayDataset(X_train, y_train, transform=train_transform)
    test_ds  = XRayDataset(X_test,  y_test,  transform=test_transform)
    train_dl = DataLoader(train_ds, batch_size=BATCH, sampler=sampler,
                          num_workers=0, pin_memory=pin_mem)
    test_dl  = DataLoader(test_ds,  batch_size=BATCH, shuffle=False,
                          num_workers=0, pin_memory=pin_mem)

    # Build model
    model     = build_resnet50().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)
    criterion = nn.CrossEntropyLoss()
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=2)

    # Early stopping variables
    best_loss      = float('inf')
    patience_ctr   = 0
    best_model_wts = None

    # Train
    model.train()
    for epoch in range(EPOCHS):
        total_loss = 0
        correct    = 0
        total      = 0

        for xb, yb in train_dl:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            outputs = model(xb)
            loss    = criterion(outputs, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            preds      = torch.argmax(outputs, dim=1)
            correct   += (preds == yb).sum().item()
            total     += yb.size(0)

        avg_loss  = total_loss / len(train_dl)
        train_acc = correct / total
        scheduler.step(avg_loss)
        print(f"  Epoch {epoch+1:02d}/{EPOCHS}  "
              f"loss={avg_loss:.4f}  train_acc={train_acc:.4f}")

        # Early stopping check
        if avg_loss < best_loss:
            best_loss      = avg_loss
            patience_ctr   = 0
            best_model_wts = {k: v.clone() for k, v in model.state_dict().items()}
            print(f"  ✓ Best model saved at epoch {epoch+1}")
        else:
            patience_ctr += 1
            print(f"  No improvement ({patience_ctr}/{PATIENCE})")
            if patience_ctr >= PATIENCE:
                print(f"  ⚡ Early stopping triggered at epoch {epoch+1}")
                break

    # Restore best weights
    model.load_state_dict(best_model_wts)

    # Evaluate
    model.eval()
    all_preds, all_true, all_probs = [], [], []

    with torch.no_grad():
        for xb, yb in test_dl:
            xb      = xb.to(device)
            outputs = model(xb)
            probs   = torch.softmax(outputs, dim=1).cpu().numpy()
            preds   = np.argmax(probs, axis=1)
            all_probs.extend(probs)
            all_preds.extend(preds)
            all_true.extend(yb.numpy())

    acc  = accuracy_score(all_true, all_preds)
    prec = precision_score(all_true, all_preds, average='macro', zero_division=0)
    rec  = recall_score(all_true, all_preds, average='macro', zero_division=0)
    f1   = f1_score(all_true, all_preds, average='macro', zero_division=0)

    results.append({"Run": run, "Accuracy": acc, "Precision": prec,
                    "Recall": rec, "F1 Score": f1})
    print(f"\nRun {run} → Acc={acc:.4f}  Prec={prec:.4f}  "
          f"Rec={rec:.4f}  F1={f1:.4f}")

    if run == NUM_RUNS:
        y_test_last  = all_true
        y_pred_last  = all_preds
        y_probs_last = np.array(all_probs)

    # Clear GPU memory between runs
    del model
    torch.cuda.empty_cache()
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 3050 Laptop GPU
#
# =======================================================
#   RUN 1  [seed=42]
# =======================================================
#   Epoch 01/50  loss=0.5661  train_acc=0.7588
#   ✓ Best model saved at epoch 1
#   Epoch 02/50  loss=0.4270  train_acc=0.8226
#   ✓ Best model saved at epoch 2
#   Epoch 03/50  loss=0.3910  train_acc=0.8399
#   ✓ Best model saved at epoch 3
#   Epoch 04/50  loss=0.3650  train_acc=0.8476
#   ✓ Best model saved at epoch 4
#   Epoch 05/50  loss=0.3478  train_acc=0.8529
#   ✓ Best model saved at epoch 5
#   Epoch 06/50  loss=0.3233  train_acc=0.8672
#   ✓ Best model saved at epoch 6
#   Epoch 07/50  loss=0.2981  train_acc=0.8781
#   ✓ Best model saved at epoch 7
#   Epoch 08/50  loss=0.2664  train_acc=0.8997
#   ✓ Best model saved at epoch 8
#   Epoch 09/50  loss=0.2465  train_acc=0.9016
#   ✓ Best model saved at epoch 9
#   Epoch 10/50  loss=0.2382  train_acc=0.9114
#   ✓ Best model saved at epoch 10
#   Epoch 11/50  loss=0.2363  train_acc=0.9082
#   ✓ Best model saved at epoch 11
#   Epoch 12/50  loss=0.2195  train_acc=0.9125
#   ✓ Best model saved at epoch 12
#   Epoch 13/50  loss=0.1933  train_acc=0.9255
#   ✓ Best model saved at epoch 13
#   Epoch 14/50  loss=0.2039  train_acc=0.9214
#   No improvement (1/5)
#   Epoch 15/50  loss=0.1836  train_acc=0.9289
#   ✓ Best model saved at epoch 15
#   Epoch 16/50  loss=0.1558  train_acc=0.9424
#   ✓ Best model saved at epoch 16
#   Epoch 17/50  loss=0.1729  train_acc=0.9377
#   No improvement (1/5)
#   Epoch 18/50  loss=0.1370  train_acc=0.9485
#   ✓ Best model saved at epoch 18
#   Epoch 19/50  loss=0.1474  train_acc=0.9443
#   No improvement (1/5)
#   Epoch 20/50  loss=0.1314  train_acc=0.9535
#   ✓ Best model saved at epoch 20
#   Epoch 21/50  loss=0.1356  train_acc=0.9511
#   No improvement (1/5)
#   Epoch 22/50  loss=0.1149  train_acc=0.9575
#   ✓ Best model saved at epoch 22
#   Epoch 23/50  loss=0.1202  train_acc=0.9562
#   No improvement (1/5)
#   Epoch 24/50  loss=0.1217  train_acc=0.9560
#   No improvement (2/5)
#   Epoch 25/50  loss=0.1267  train_acc=0.9539
#   No improvement (3/5)
#   Epoch 26/50  loss=0.0912  train_acc=0.9661
#   ✓ Best model saved at epoch 26
#   Epoch 27/50  loss=0.0736  train_acc=0.9750
#   ✓ Best model saved at epoch 27
#   Epoch 28/50  loss=0.0657  train_acc=0.9778
#   ✓ Best model saved at epoch 28
#   Epoch 29/50  loss=0.0578  train_acc=0.9782
#   ✓ Best model saved at epoch 29
#   Epoch 30/50  loss=0.0552  train_acc=0.9797
#   ✓ Best model saved at epoch 30
#   Epoch 31/50  loss=0.0589  train_acc=0.9776
#   No improvement (1/5)
#   Epoch 32/50  loss=0.0476  train_acc=0.9836
#   ✓ Best model saved at epoch 32
#   Epoch 33/50  loss=0.0445  train_acc=0.9848
#   ✓ Best model saved at epoch 33
#   Epoch 34/50  loss=0.0401  train_acc=0.9851
#   ✓ Best model saved at epoch 34
#   Epoch 35/50  loss=0.0526  train_acc=0.9819
#   No improvement (1/5)
#   Epoch 36/50  loss=0.0421  train_acc=0.9859
#   No improvement (2/5)
#   Epoch 37/50  loss=0.0434  train_acc=0.9838
#   No improvement (3/5)
#   Epoch 38/50  loss=0.0388  train_acc=0.9874
#   ✓ Best model saved at epoch 38
#   Epoch 39/50  loss=0.0493  train_acc=0.9812
#   No improvement (1/5)
#   Epoch 40/50  loss=0.0373  train_acc=0.9868
#   ✓ Best model saved at epoch 40
#   Epoch 41/50  loss=0.0407  train_acc=0.9859
#   No improvement (1/5)
#   Epoch 42/50  loss=0.0347  train_acc=0.9889
#   ✓ Best model saved at epoch 42
#   Epoch 43/50  loss=0.0483  train_acc=0.9846
#   No improvement (1/5)
#   Epoch 44/50  loss=0.0359  train_acc=0.9872
#   No improvement (2/5)
#   Epoch 45/50  loss=0.0459  train_acc=0.9829
#   No improvement (3/5)
#   Epoch 46/50  loss=0.0307  train_acc=0.9891
#   ✓ Best model saved at epoch 46
#   Epoch 47/50  loss=0.0353  train_acc=0.9893
#   No improvement (1/5)
#   Epoch 48/50  loss=0.0386  train_acc=0.9868
#   No improvement (2/5)
#   Epoch 49/50  loss=0.0327  train_acc=0.9912
#   No improvement (3/5)
#   Epoch 50/50  loss=0.0351  train_acc=0.9885
#   No improvement (4/5)
#
# Run 1 → Acc=0.8404  Prec=0.8402  Rec=0.8266  F1=0.8324
#
# =======================================================
#   RUN 2  [seed=7]
# =======================================================
#   Epoch 01/50  loss=0.5367  train_acc=0.7696
#   ✓ Best model saved at epoch 1
#   Epoch 02/50  loss=0.4395  train_acc=0.8134
#   ✓ Best model saved at epoch 2
#   Epoch 03/50  loss=0.4010  train_acc=0.8311
#   ✓ Best model saved at epoch 3
#   Epoch 04/50  loss=0.3657  train_acc=0.8484
#   ✓ Best model saved at epoch 4
#   Epoch 05/50  loss=0.3457  train_acc=0.8503
#   ✓ Best model saved at epoch 5
#   Epoch 06/50  loss=0.3427  train_acc=0.8678
#   ✓ Best model saved at epoch 6
#   Epoch 07/50  loss=0.3098  train_acc=0.8753
#   ✓ Best model saved at epoch 7
#   Epoch 08/50  loss=0.2836  train_acc=0.8896
#   ✓ Best model saved at epoch 8
#   Epoch 09/50  loss=0.2748  train_acc=0.8928
#   ✓ Best model saved at epoch 9
#   Epoch 10/50  loss=0.2387  train_acc=0.9086
#   ✓ Best model saved at epoch 10
#   Epoch 11/50  loss=0.2215  train_acc=0.9148
#   ✓ Best model saved at epoch 11
#   Epoch 12/50  loss=0.2243  train_acc=0.9176
#   No improvement (1/5)
#   Epoch 13/50  loss=0.2061  train_acc=0.9229
#   ✓ Best model saved at epoch 13
#   Epoch 14/50  loss=0.1995  train_acc=0.9263
#   ✓ Best model saved at epoch 14
#   Epoch 15/50  loss=0.1714  train_acc=0.9377
#   ✓ Best model saved at epoch 15
#   Epoch 16/50  loss=0.1742  train_acc=0.9377
#   No improvement (1/5)
#   Epoch 17/50  loss=0.1564  train_acc=0.9430
#   ✓ Best model saved at epoch 17
#   Epoch 18/50  loss=0.1591  train_acc=0.9383
#   No improvement (1/5)
#   Epoch 19/50  loss=0.1518  train_acc=0.9426
#   ✓ Best model saved at epoch 19
#   Epoch 20/50  loss=0.1272  train_acc=0.9558
#   ✓ Best model saved at epoch 20
#   Epoch 21/50  loss=0.1373  train_acc=0.9483
#   No improvement (1/5)
#   Epoch 22/50  loss=0.1275  train_acc=0.9545
#   No improvement (2/5)
#   Epoch 23/50  loss=0.1215  train_acc=0.9537
#   ✓ Best model saved at epoch 23
#   Epoch 24/50  loss=0.1106  train_acc=0.9599
#   ✓ Best model saved at epoch 24
#   Epoch 25/50  loss=0.1022  train_acc=0.9611
#   ✓ Best model saved at epoch 25
#   Epoch 26/50  loss=0.1027  train_acc=0.9635
#   No improvement (1/5)
#   Epoch 27/50  loss=0.1021  train_acc=0.9635
#   ✓ Best model saved at epoch 27
#   Epoch 28/50  loss=0.0968  train_acc=0.9661
#   ✓ Best model saved at epoch 28
#   Epoch 29/50  loss=0.0994  train_acc=0.9616
#   No improvement (1/5)
#   Epoch 30/50  loss=0.0744  train_acc=0.9748
#   ✓ Best model saved at epoch 30
#   Epoch 31/50  loss=0.0901  train_acc=0.9673
#   No improvement (1/5)
#   Epoch 32/50  loss=0.0756  train_acc=0.9733
#   No improvement (2/5)
#   Epoch 33/50  loss=0.0870  train_acc=0.9682
#   No improvement (3/5)
#   Epoch 34/50  loss=0.0579  train_acc=0.9787
#   ✓ Best model saved at epoch 34
#   Epoch 35/50  loss=0.0431  train_acc=0.9857
#   ✓ Best model saved at epoch 35
#   Epoch 36/50  loss=0.0424  train_acc=0.9883
#   ✓ Best model saved at epoch 36
#   Epoch 37/50  loss=0.0440  train_acc=0.9844
#   No improvement (1/5)
#   Epoch 38/50  loss=0.0327  train_acc=0.9878
#   ✓ Best model saved at epoch 38
#   Epoch 39/50  loss=0.0444  train_acc=0.9870
#   No improvement (1/5)
#   Epoch 40/50  loss=0.0275  train_acc=0.9902
#   ✓ Best model saved at epoch 40
#   Epoch 41/50  loss=0.0284  train_acc=0.9898
#   No improvement (1/5)
#   Epoch 42/50  loss=0.0299  train_acc=0.9889
#   No improvement (2/5)
#   Epoch 43/50  loss=0.0371  train_acc=0.9874
#   No improvement (3/5)
#   Epoch 44/50  loss=0.0290  train_acc=0.9891
#   No improvement (4/5)
#   Epoch 45/50  loss=0.0251  train_acc=0.9919
#   ✓ Best model saved at epoch 45
#   Epoch 46/50  loss=0.0266  train_acc=0.9880
#   No improvement (1/5)
#   Epoch 47/50  loss=0.0203  train_acc=0.9932
#   ✓ Best model saved at epoch 47
#   Epoch 48/50  loss=0.0249  train_acc=0.9921
#   No improvement (1/5)
#   Epoch 49/50  loss=0.0268  train_acc=0.9921
#   No improvement (2/5)
#   Epoch 50/50  loss=0.0306  train_acc=0.9885
#   No improvement (3/5)
#
# Run 2 → Acc=0.8584  Prec=0.8544  Rec=0.8468  F1=0.8501
#
# =======================================================
#   RUN 3  [seed=99]
# =======================================================
#   Epoch 01/50  loss=0.5571  train_acc=0.7637
#   ✓ Best model saved at epoch 1
#   Epoch 02/50  loss=0.4270  train_acc=0.8209
#   ✓ Best model saved at epoch 2
#   Epoch 03/50  loss=0.3934  train_acc=0.8339
#   ✓ Best model saved at epoch 3
#   Epoch 04/50  loss=0.3578  train_acc=0.8533
#   ✓ Best model saved at epoch 4
#   Epoch 05/50  loss=0.3306  train_acc=0.8653
#   ✓ Best model saved at epoch 5
#   Epoch 06/50  loss=0.3117  train_acc=0.8760
#   ✓ Best model saved at epoch 6
#   Epoch 07/50  loss=0.2788  train_acc=0.8888
#   ✓ Best model saved at epoch 7
#   Epoch 08/50  loss=0.2624  train_acc=0.8969
#   ✓ Best model saved at epoch 8
#   Epoch 09/50  loss=0.2616  train_acc=0.8971
#   ✓ Best model saved at epoch 9
#   Epoch 10/50  loss=0.2344  train_acc=0.9110
#   ✓ Best model saved at epoch 10
#   Epoch 11/50  loss=0.2018  train_acc=0.9202
#   ✓ Best model saved at epoch 11
#   Epoch 12/50  loss=0.1991  train_acc=0.9272
#   ✓ Best model saved at epoch 12
#   Epoch 13/50  loss=0.2055  train_acc=0.9234
#   No improvement (1/5)
#   Epoch 14/50  loss=0.1876  train_acc=0.9251
#   ✓ Best model saved at epoch 14
#   Epoch 15/50  loss=0.1678  train_acc=0.9349
#   ✓ Best model saved at epoch 15
#   Epoch 16/50  loss=0.1499  train_acc=0.9468
#   ✓ Best model saved at epoch 16
#   Epoch 17/50  loss=0.1577  train_acc=0.9404
#   No improvement (1/5)
#   Epoch 18/50  loss=0.1405  train_acc=0.9458
#   ✓ Best model saved at epoch 18
#   Epoch 19/50  loss=0.1375  train_acc=0.9492
#   ✓ Best model saved at epoch 19
#   Epoch 20/50  loss=0.1362  train_acc=0.9485
#   ✓ Best model saved at epoch 20
#   Epoch 21/50  loss=0.1115  train_acc=0.9575
#   ✓ Best model saved at epoch 21
#   Epoch 22/50  loss=0.1269  train_acc=0.9535
#   No improvement (1/5)
#   Epoch 23/50  loss=0.1208  train_acc=0.9552
#   No improvement (2/5)
#   Epoch 24/50  loss=0.1054  train_acc=0.9629
#   ✓ Best model saved at epoch 24
#   Epoch 25/50  loss=0.1115  train_acc=0.9601
#   No improvement (1/5)
#   Epoch 26/50  loss=0.0938  train_acc=0.9669
#   ✓ Best model saved at epoch 26
#   Epoch 27/50  loss=0.0921  train_acc=0.9697
#   ✓ Best model saved at epoch 27
#   Epoch 28/50  loss=0.0800  train_acc=0.9722
#   ✓ Best model saved at epoch 28
#   Epoch 29/50  loss=0.0939  train_acc=0.9675
#   No improvement (1/5)
#   Epoch 30/50  loss=0.0848  train_acc=0.9697
#   No improvement (2/5)
#   Epoch 31/50  loss=0.0860  train_acc=0.9680
#   No improvement (3/5)
#   Epoch 32/50  loss=0.0501  train_acc=0.9821
#   ✓ Best model saved at epoch 32
#   Epoch 33/50  loss=0.0537  train_acc=0.9814
#   No improvement (1/5)
#   Epoch 34/50  loss=0.0434  train_acc=0.9853
#   ✓ Best model saved at epoch 34
#   Epoch 35/50  loss=0.0368  train_acc=0.9880
#   ✓ Best model saved at epoch 35
#   Epoch 36/50  loss=0.0365  train_acc=0.9865
#   ✓ Best model saved at epoch 36
#   Epoch 37/50  loss=0.0339  train_acc=0.9887
#   ✓ Best model saved at epoch 37
#   Epoch 38/50  loss=0.0402  train_acc=0.9853
#   No improvement (1/5)
#   Epoch 39/50  loss=0.0324  train_acc=0.9880
#   ✓ Best model saved at epoch 39
#   Epoch 40/50  loss=0.0291  train_acc=0.9908
#   ✓ Best model saved at epoch 40
#   Epoch 41/50  loss=0.0316  train_acc=0.9887
#   No improvement (1/5)
#   Epoch 42/50  loss=0.0296  train_acc=0.9908
#   No improvement (2/5)
#   Epoch 43/50  loss=0.0299  train_acc=0.9908
#   No improvement (3/5)
#   Epoch 44/50  loss=0.0229  train_acc=0.9930
#   ✓ Best model saved at epoch 44
#   Epoch 45/50  loss=0.0262  train_acc=0.9908
#   No improvement (1/5)
#   Epoch 46/50  loss=0.0299  train_acc=0.9900
#   No improvement (2/5)
#   Epoch 47/50  loss=0.0254  train_acc=0.9917
#   No improvement (3/5)
#   Epoch 48/50  loss=0.0296  train_acc=0.9904
#   No improvement (4/5)
#   Epoch 49/50  loss=0.0240  train_acc=0.9923
#   No improvement (5/5)
#   ⚡ Early stopping triggered at epoch 49
#
# Run 3 → Acc=0.8464  Prec=0.8404  Rec=0.8409  F1=0.8407
#
# =======================================================
#   RUN 4  [seed=2024]
# =======================================================
#   Epoch 01/50  loss=0.5422  train_acc=0.7654
#   ✓ Best model saved at epoch 1
#   Epoch 02/50  loss=0.4137  train_acc=0.8277
#   ✓ Best model saved at epoch 2
#   Epoch 03/50  loss=0.3892  train_acc=0.8367
#   ✓ Best model saved at epoch 3
#   Epoch 04/50  loss=0.3687  train_acc=0.8420
#   ✓ Best model saved at epoch 4
#   Epoch 05/50  loss=0.3204  train_acc=0.8704
#   ✓ Best model saved at epoch 5
#   Epoch 06/50  loss=0.3169  train_acc=0.8747
#   ✓ Best model saved at epoch 6
#   Epoch 07/50  loss=0.2791  train_acc=0.8883
#   ✓ Best model saved at epoch 7
#   Epoch 08/50  loss=0.2784  train_acc=0.8973
#   ✓ Best model saved at epoch 8
#   Epoch 09/50  loss=0.2616  train_acc=0.9007
#   ✓ Best model saved at epoch 9
#   Epoch 10/50  loss=0.2325  train_acc=0.9118
#   ✓ Best model saved at epoch 10
#   Epoch 11/50  loss=0.2136  train_acc=0.9170
#   ✓ Best model saved at epoch 11
#   Epoch 12/50  loss=0.2227  train_acc=0.9135
#   No improvement (1/5)
#   Epoch 13/50  loss=0.1956  train_acc=0.9223
#   ✓ Best model saved at epoch 13
#   Epoch 14/50  loss=0.1664  train_acc=0.9349
#   ✓ Best model saved at epoch 14
#   Epoch 15/50  loss=0.1703  train_acc=0.9385
#   No improvement (1/5)
#   Epoch 16/50  loss=0.1583  train_acc=0.9449
#   ✓ Best model saved at epoch 16
#   Epoch 17/50  loss=0.1485  train_acc=0.9475
#   ✓ Best model saved at epoch 17
#   Epoch 18/50  loss=0.1508  train_acc=0.9413
#   No improvement (1/5)
#   Epoch 19/50  loss=0.1364  train_acc=0.9507
#   ✓ Best model saved at epoch 19
#   Epoch 20/50  loss=0.1252  train_acc=0.9515
#   ✓ Best model saved at epoch 20
#   Epoch 21/50  loss=0.1236  train_acc=0.9532
#   ✓ Best model saved at epoch 21
#   Epoch 22/50  loss=0.1190  train_acc=0.9594
#   ✓ Best model saved at epoch 22
#   Epoch 23/50  loss=0.1234  train_acc=0.9554
#   No improvement (1/5)
#   Epoch 24/50  loss=0.1058  train_acc=0.9614
#   ✓ Best model saved at epoch 24
#   Epoch 25/50  loss=0.1211  train_acc=0.9564
#   No improvement (1/5)
#   Epoch 26/50  loss=0.1087  train_acc=0.9626
#   No improvement (2/5)
#   Epoch 27/50  loss=0.0981  train_acc=0.9637
#   ✓ Best model saved at epoch 27
#   Epoch 28/50  loss=0.0882  train_acc=0.9693
#   ✓ Best model saved at epoch 28
#   Epoch 29/50  loss=0.0932  train_acc=0.9641
#   No improvement (1/5)
#   Epoch 30/50  loss=0.0929  train_acc=0.9673
#   No improvement (2/5)
#   Epoch 31/50  loss=0.0880  train_acc=0.9673
#   ✓ Best model saved at epoch 31
#   Epoch 32/50  loss=0.0727  train_acc=0.9746
#   ✓ Best model saved at epoch 32
#   Epoch 33/50  loss=0.0885  train_acc=0.9684
#   No improvement (1/5)
#   Epoch 34/50  loss=0.0747  train_acc=0.9722
#   No improvement (2/5)
#   Epoch 35/50  loss=0.0703  train_acc=0.9746
#   ✓ Best model saved at epoch 35
#   Epoch 36/50  loss=0.0742  train_acc=0.9746
#   No improvement (1/5)
#   Epoch 37/50  loss=0.0653  train_acc=0.9769
#   ✓ Best model saved at epoch 37
#   Epoch 38/50  loss=0.0619  train_acc=0.9769
#   ✓ Best model saved at epoch 38
#   Epoch 39/50  loss=0.0686  train_acc=0.9750
#   No improvement (1/5)
#   Epoch 40/50  loss=0.0754  train_acc=0.9729
#   No improvement (2/5)
#   Epoch 41/50  loss=0.0578  train_acc=0.9793
#   ✓ Best model saved at epoch 41
#   Epoch 42/50  loss=0.0664  train_acc=0.9754
#   No improvement (1/5)
#   Epoch 43/50  loss=0.0563  train_acc=0.9810
#   ✓ Best model saved at epoch 43
#   Epoch 44/50  loss=0.0581  train_acc=0.9797
#   No improvement (1/5)
#   Epoch 45/50  loss=0.0566  train_acc=0.9842
#   No improvement (2/5)
#   Epoch 46/50  loss=0.0711  train_acc=0.9742
#   No improvement (3/5)
#   Epoch 47/50  loss=0.0490  train_acc=0.9827
#   ✓ Best model saved at epoch 47
#   Epoch 48/50  loss=0.0391  train_acc=0.9859
#   ✓ Best model saved at epoch 48
#   Epoch 49/50  loss=0.0402  train_acc=0.9874
#   No improvement (1/5)
#   Epoch 50/50  loss=0.0276  train_acc=0.9921
#   ✓ Best model saved at epoch 50
#
# Run 4 → Acc=0.8481  Prec=0.8501  Rec=0.8329  F1=0.8403
#
# =======================================================
#   RUN 5  [seed=13]
# =======================================================
#   Epoch 01/50  loss=0.5355  train_acc=0.7767
#   ✓ Best model saved at epoch 1
#   Epoch 02/50  loss=0.4408  train_acc=0.8134
#   ✓ Best model saved at epoch 2
#   Epoch 03/50  loss=0.3896  train_acc=0.8384
#   ✓ Best model saved at epoch 3
#   Epoch 04/50  loss=0.3628  train_acc=0.8514
#   ✓ Best model saved at epoch 4
#   Epoch 05/50  loss=0.3214  train_acc=0.8728
#   ✓ Best model saved at epoch 5
#   Epoch 06/50  loss=0.3164  train_acc=0.8751
#   ✓ Best model saved at epoch 6
#   Epoch 07/50  loss=0.2895  train_acc=0.8877
#   ✓ Best model saved at epoch 7
#   Epoch 08/50  loss=0.2727  train_acc=0.8965
#   ✓ Best model saved at epoch 8
#   Epoch 09/50  loss=0.2597  train_acc=0.8898
#   ✓ Best model saved at epoch 9
#   Epoch 10/50  loss=0.2406  train_acc=0.9029
#   ✓ Best model saved at epoch 10
#   Epoch 11/50  loss=0.2292  train_acc=0.9110
#   ✓ Best model saved at epoch 11
#   Epoch 12/50  loss=0.2204  train_acc=0.9163
#   ✓ Best model saved at epoch 12
#   Epoch 13/50  loss=0.1997  train_acc=0.9261
#   ✓ Best model saved at epoch 13
#   Epoch 14/50  loss=0.1824  train_acc=0.9298
#   ✓ Best model saved at epoch 14
#   Epoch 15/50  loss=0.1858  train_acc=0.9295
#   No improvement (1/5)
#   Epoch 16/50  loss=0.1647  train_acc=0.9417
#   ✓ Best model saved at epoch 16
#   Epoch 17/50  loss=0.1663  train_acc=0.9389
#   No improvement (1/5)
#   Epoch 18/50  loss=0.1397  train_acc=0.9500
#   ✓ Best model saved at epoch 18
#   Epoch 19/50  loss=0.1268  train_acc=0.9588
#   ✓ Best model saved at epoch 19
#   Epoch 20/50  loss=0.1332  train_acc=0.9518
#   No improvement (1/5)
#   Epoch 21/50  loss=0.1505  train_acc=0.9398
#   No improvement (2/5)
#   Epoch 22/50  loss=0.1256  train_acc=0.9528
#   ✓ Best model saved at epoch 22
#   Epoch 23/50  loss=0.1183  train_acc=0.9556
#   ✓ Best model saved at epoch 23
#   Epoch 24/50  loss=0.1174  train_acc=0.9537
#   ✓ Best model saved at epoch 24
#   Epoch 25/50  loss=0.1167  train_acc=0.9558
#   ✓ Best model saved at epoch 25
#   Epoch 26/50  loss=0.0881  train_acc=0.9703
#   ✓ Best model saved at epoch 26
#   Epoch 27/50  loss=0.1022  train_acc=0.9626
#   No improvement (1/5)
#   Epoch 28/50  loss=0.0871  train_acc=0.9684
#   ✓ Best model saved at epoch 28
#   Epoch 29/50  loss=0.1169  train_acc=0.9635
#   No improvement (1/5)
#   Epoch 30/50  loss=0.0969  train_acc=0.9675
#   No improvement (2/5)
#   Epoch 31/50  loss=0.0923  train_acc=0.9669
#   No improvement (3/5)
#   Epoch 32/50  loss=0.0799  train_acc=0.9720
#   ✓ Best model saved at epoch 32
#   Epoch 33/50  loss=0.0578  train_acc=0.9806
#   ✓ Best model saved at epoch 33
#   Epoch 34/50  loss=0.0484  train_acc=0.9844
#   ✓ Best model saved at epoch 34
#   Epoch 35/50  loss=0.0481  train_acc=0.9855
#   ✓ Best model saved at epoch 35
#   Epoch 36/50  loss=0.0446  train_acc=0.9851
#   ✓ Best model saved at epoch 36
#   Epoch 37/50  loss=0.0348  train_acc=0.9872
#   ✓ Best model saved at epoch 37
#   Epoch 38/50  loss=0.0398  train_acc=0.9870
#   No improvement (1/5)
#   Epoch 39/50  loss=0.0278  train_acc=0.9908
#   ✓ Best model saved at epoch 39
#   Epoch 40/50  loss=0.0349  train_acc=0.9870
#   No improvement (1/5)
#   Epoch 41/50  loss=0.0318  train_acc=0.9912
#   No improvement (2/5)
#   Epoch 42/50  loss=0.0309  train_acc=0.9902
#   No improvement (3/5)
#   Epoch 43/50  loss=0.0291  train_acc=0.9912
#   No improvement (4/5)
#   Epoch 44/50  loss=0.0256  train_acc=0.9936
#   ✓ Best model saved at epoch 44
#   Epoch 45/50  loss=0.0280  train_acc=0.9910
#   No improvement (1/5)
#   Epoch 46/50  loss=0.0294  train_acc=0.9895
#   No improvement (2/5)
#   Epoch 47/50  loss=0.0291  train_acc=0.9919
#   No improvement (3/5)
#   Epoch 48/50  loss=0.0303  train_acc=0.9904
#   No improvement (4/5)
#   Epoch 49/50  loss=0.0288  train_acc=0.9895
#   No improvement (5/5)
#   ⚡ Early stopping triggered at epoch 49
#
# Run 5 → Acc=0.8490  Prec=0.8512  Rec=0.8268  F1=0.8346

# %%
df_results = pd.DataFrame(results)
print("===== ResNet50 – Per Run Results =====")
print(df_results.to_string(index=False))
# Out:
# ===== ResNet50 – Per Run Results =====
#  Run  Accuracy  Precision   Recall  F1 Score
#    1  0.840444   0.840236 0.826550  0.832424
#    2  0.858362   0.854416 0.846807  0.850139
#    3  0.846416   0.840440 0.840927  0.840682
#    4  0.848123   0.850094 0.832905  0.840343
#    5  0.848976   0.851223 0.826814  0.834567

# %%
metrics = ["Accuracy", "Precision", "Recall", "F1 Score"]

summary = pd.DataFrame({
    "Mean" : df_results[metrics].mean(),
    "Std"  : df_results[metrics].std(),
})

print("\n===== ResNet50 – AVERAGE PERFORMANCE (5 Runs) =====")
print(summary.round(4).to_string())
# Out:
# ===== ResNet50 – AVERAGE PERFORMANCE (5 Runs) =====
#              Mean     Std
# Accuracy   0.8485  0.0065
# Precision  0.8473  0.0065
# Recall     0.8348  0.0089
# F1 Score   0.8396  0.0069

# %%
avg = df_results[metrics].mean()
std = df_results[metrics].std()

x     = np.arange(len(metrics))
width = 0.5

fig, ax = plt.subplots(figsize=(9, 5))
bars = ax.bar(x, avg, width, yerr=std, color='steelblue', capsize=5, alpha=0.85)
ax.set_ylabel('Score')
ax.set_title('ResNet50 – X-Ray Classification\nAverage Metrics over 5 Runs')
ax.set_xticks(x); ax.set_xticklabels(metrics)
ax.set_ylim(0.5, 1.05)
ax.bar_label(bars, fmt='%.4f', padding=3, fontsize=9)
ax.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout(); plt.show()

# %%
cm  = confusion_matrix(y_test_last, y_pred_last)
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, cmap='Blues')
fig.colorbar(im, ax=ax)
ax.set_xticks(range(3)); ax.set_yticks(range(3))
ax.set_xticklabels(CLASS_NAMES); ax.set_yticklabels(CLASS_NAMES)
for i in range(3):
    for j in range(3):
        ax.text(j, i, str(cm[i,j]), ha='center', va='center',
                color='white' if cm[i,j] > cm.max()/2 else 'black',
                fontsize=12, fontweight='bold')
ax.set_title('ResNet50 – Confusion Matrix (Run 5)')
ax.set_xlabel('Predicted'); ax.set_ylabel('Actual')
plt.tight_layout(); plt.show()

# %%
y_true_bin = label_binarize(y_test_last, classes=[0, 1, 2])
colors     = ['steelblue', 'tomato', 'green']

plt.figure(figsize=(8, 6))
for i, (cls_name, color) in enumerate(zip(CLASS_NAMES, colors)):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_probs_last[:, i])
    roc_auc     = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, label=f'{cls_name} (AUC = {roc_auc:.4f})')

plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve – ResNet50 X-Ray Classification')
plt.legend(); plt.grid(linestyle='--', alpha=0.5)
plt.tight_layout(); plt.show()

# %%
print("===== ResNet50 – Classification Report (Run 5) =====")
print(classification_report(y_test_last, y_pred_last,
                             target_names=CLASS_NAMES))
# Out:
# ===== ResNet50 – Classification Report (Run 5) =====
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.95      0.95       317
#    Bacterial       0.82      0.92      0.87       556
#        Viral       0.78      0.61      0.68       299
#
#     accuracy                           0.85      1172
#    macro avg       0.85      0.83      0.83      1172
# weighted avg       0.85      0.85      0.84      1172

# %%
plt.figure(figsize=(8, 4))
plt.plot(df_results["Run"], df_results["Accuracy"], 'o-', color='steelblue')
plt.xlabel('Run'); plt.ylabel('Accuracy')
plt.title('ResNet50 Accuracy per Run')
plt.xticks(df_results["Run"])
plt.grid(linestyle='--', alpha=0.5)
plt.tight_layout(); plt.show()
